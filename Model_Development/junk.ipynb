# %% [markdown]
# this is just a dump for potential ideas that are not ready to be deleted.

# %% [markdown]
# # data_wrangling.ipynb, section PREPROCESSING

# %% [markdown]
# ## Lemmatisation

# %% [markdown]
# **POTENTIAL EXPERIMENT (can use to test which performs better, with(out) lemmatisation). For now, not implemented yet**
#
# "Walk", "Walking", "Walked" and "Walks" all mean the exact same thing, just with suffixes. By removing suffixes, we are able to reduce the words to their base form ("walk") and reduce the vocabulary size (and increase the models generalisation).

# %%
lemmatizer = WordNetLemmatizer()

def get_part_of_speech(text):
    tag = nltk.pos_tag(nltk.tokenize.word_tokenize(text))
    return tag
# Out:
# [('Hello', 'NNP'), ('World', 'NNP')]
